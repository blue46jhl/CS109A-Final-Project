# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn.linear_model import LassoCV

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import zipfile


import seaborn as sns
sns.set()

# %%
tweets = pd.read_csv('data/TrumpTweetsFinal.csv', encoding='utf-8')
tweets2 = tweets.iloc[::-1].reset_index().drop(['index'], axis = 1)
tweets2 = tweets2[tweets2['is_retweet'] == False]
tweets2['created_at'] = pd.to_datetime(tweets2['created_at'])
tweets2.to_csv('data/TrumpTweetsCleaned.csv', index = False)

# %%
tweets.head(-5)
tweets.iloc[12808].text
# Out:
# 'Join me in Florida tomorrow!MIAMI‚Ä¢12pmhttps://t.co/A3X71Q6sG2ORLANDO‚Ä¢4pmhttps://t.co/6BqTVoty5CPENSACOLA‚Ä¢7p‚Ä¶ https://t.co/kEQuuJeO1B'

# %%
tweets2.head(-5)
# Out:
#                                                     text          created_at  \
# 0      Look at the way Crooked Hillary is handling th... 2016-11-01 10:31:00
# 1      Wow now leading in @ABC /@washingtonpost Poll ... 2016-11-01 11:55:00
# 2      Crooked Hillary should not be allowed to run f... 2016-11-01 12:01:00
# 3      JOIN ME TOMORROW IN FLORIDA!MIAMI‚Ä¢12pmhttps:... 2016-11-01 13:35:00
# 4      So terrible that Crooked didn't report she got... 2016-11-01 14:14:00
# 5      #ICYMI: Governor @mike_pence and I were in Val... 2016-11-01 17:24:00
# 6      .@DarrellIssa is a very good man. Help him win... 2016-11-01 18:44:00
# 7      'Kept me out of jail': Top DOJ official involv... 2016-11-01 21:15:00
# 8      Trump promises special session to repeal Obama... 2016-11-01 21:16:00
# 9      Hillary Advisers Wanted Her To Avoid Supportin... 2016-11-01 21:20:00
# 10     Mika Brzezinski: Dem Criticism of Comey Reinfo... 2016-11-01 21:28:00
# ...

# %%
tweets2.iloc[3].text
# Out:
# 'JOIN ME TOMORROW IN FLORIDA!MIAMI‚Ä¢12pmhttps://t.co/A3X71Q6sG2ORLANDO‚Ä¢4pmhttps://t.co/6BqTVoty5CPENSACOLA‚Ä¢7p‚Ä¶ https://t.co/kNzrAeuLZO'

# %%
s = '•'

# %%
# Out:
# '•'

# %%
from googlefinance.get import get_code

# %%
from googlefinance.get import get_datum
df = get_datum('NASDAQ:TSLA', period='2M', interval =86400)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume]
# Index: []
